# %% [markdown]
# # 7. 임계값 튜닝 (Threshold Tuning)
#
# `val_calib` 데이터로 **FPR 상한별 Recall 표**를 먼저 출력하고, 이어서 **FPR–Recall 곡선**을 그립니다.
# (1% 안에서 자동 최적화하지 않음 — 표를 보고 운영점을 결정. 08번용 저장은 `SAVE_OPERATING_FPR_CAP` 행 사용)
#
# **사전 조건**
# 1. `data/split_group_stratified/val_calib_raw.parquet` — `03_data_splitting.ipynb` (README 데이터 분할 후 다운로드)
# 2. `data/split_group_stratified/val_calib.parquet` — `06a_feature_engineering.ipynb`
# 3. `06c_training_optuna.ipynb` 완료 → `models/.../subset_*.pkl`

# %%
import sys, os
sys.path.insert(0, os.path.abspath("..\\"))

from src.eval_core import run_threshold_tuning_from_saved_model
import config.threshold_config as cfg

result = run_threshold_tuning_from_saved_model(
    cfg,
    show_plots=True,
    save=True,
)

THRESHOLD = result["threshold"]
THRESHOLD
# Out:
# [§7] 시작 — 디스크 단위 롤링 임계값 튜닝 (val_calib)
# [§7] 1/5 — 경로·산출물 확인
#
# [Data Path Contract]
#   [OK] model save directory: C:\Workspace\06_ML_projdect\26_1_COIN\models\underbagging_ensemble_4
#   [OK] val_calib feature data: C:\Workspace\06_ML_projdect\26_1_COIN\data\split_group_stratified\val_calib.parquet (406,555,531 bytes)
# [§7] 2/5 — 앙상블 모델 로드
#
# [Data Path Contract]
#   [OK] model save directory: C:\Workspace\06_ML_projdect\26_1_COIN\models\underbagging_ensemble_4
#   [OK] feature columns: C:\Workspace\06_ML_projdect\26_1_COIN\models\underbagging_ensemble_4\feature_cols.json (591 bytes)
# [Model Artifact Contract]
#   model_dir: C:\Workspace\06_ML_projdect\26_1_COIN\models\underbagging_ensemble_4
#   feature_cols: C:\Workspace\06_ML_projdect\26_1_COIN\models\underbagging_ensemble_4\feature_cols.json (27 features)
#   model: subset_00.pkl (9,539,044 bytes)
#   model: subset_01.pkl (9,555,780 bytes)
#   model: subset_02.pkl (9,557,204 bytes)
# ...
